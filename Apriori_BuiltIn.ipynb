# %% [markdown]
# # Built-In Apriori Algorithm Implementation

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
def select_amazon():
    print("The store you selected is Amazon")
    file_name = "amazon_transactions.csv"
    df = pd.read_csv(file_name, usecols=["Transaction"])
    transaction_list = df["Transaction"].tolist()
    dataset = [transaction.split(', ') for transaction in transaction_list]
    return dataset

# %%
def select_bestbuy():
    print("The store you selected is Best Buy")
    file_name = "bestbuy_transactions.csv"
    df = pd.read_csv(file_name, usecols=["Transaction"])
    transaction_list = df["Transaction"].tolist()
    dataset = [transaction.split(', ') for transaction in transaction_list]
    return dataset

# %%
def select_nike():
    print("The store you selected is Nike")
    file_name = "nike_transactions.csv"
    df = pd.read_csv(file_name, usecols=["Transaction"])
    transaction_list = df["Transaction"].tolist()
    dataset = [transaction.split(', ') for transaction in transaction_list]
    return dataset

# %%
def select_kmart():
    print("The store you selected is KMart")
    file_name = "kmart_transactions.csv"
    df = pd.read_csv(file_name, usecols=["Transaction"])
    transaction_list = df["Transaction"].tolist()
    dataset = [transaction.split(', ') for transaction in transaction_list]
    return dataset

# %%
def select_homedepot():
    print("The store you selected is Home Depot")
    file_name = "homedepot_transactions.csv"
    df = pd.read_csv(file_name, usecols=["Transaction"])
    transaction_list = df["Transaction"].tolist()
    dataset = [transaction.split(', ') for transaction in transaction_list]
    return dataset

# %%
def main():
    while True:
        print("Please select the store")
        print("1. Amazon")
        print("2. Best Buy")
        print("3. Nike")
        print("4. KMart")
        print("5. Home Depot")
        print("6. Exit")
        choice = input("Enter your choice: ")

        if choice == '1':
            dataset = select_amazon()
            break 
        elif choice == '2':
            dataset = select_bestbuy()
            break 
        elif choice == '3':
            dataset = select_nike()
            break
        elif choice == '4':
            dataset = select_kmart()
            break
        elif choice == '5':
            dataset = select_homedepot()
            break
        elif choice == '6':
            print("Exiting the program.")
            break
        else:
            print("Invalid Choice. Please try again.")

    if choice in ['1', '2', '3', '4', '5']:
        min_support = float(input("Enter minimum support (0-1):"))
        min_confidence = float(input("Enter minimum confidence (0-1):"))
        if min_support > 1:
            min_support = 1
        elif min_support <= 0:
            min_support = 0.1
        elif min_confidence > 1:
            min_confidence = 1
        elif min_confidence <= 0:
            min_confidence = 0.1
         
    return dataset, min_support, min_confidence

dataset, min_support, min_confidence = main()
# Out:
# Please select the store
# 1. Amazon
# 2. Best Buy
# 3. Nike
# 4. KMart
# 5. Home Depot
# 6. Exit
# Enter your choice:  3
# The store you selected is Nike
# Enter minimum support (0-1): 0.5
# Enter minimum confidence (0-1): 0.7

# %%
dataset
# Out:
# [['Running Shoe', 'Socks', 'Sweatshirts', 'Modern Pants'],
#  ['Running Shoe', 'Socks', 'Sweatshirts'],
#  ['Running Shoe', 'Socks', 'Sweatshirts', 'Modern Pants'],
#  ['Running Shoe', 'Sweatshirts', 'Modern Pants'],
#  ['Running Shoe', 'Socks', 'Sweatshirts', 'Modern Pants', 'Soccer Shoe'],
#  ['Running Shoe', 'Socks', 'Sweatshirts'],
#  ['Running Shoe',
#   'Socks',
#   'Sweatshirts',
#   'Modern Pants',
#   'Tech Pants',
#   'Rash Guard',
#   'Hoodies'],
#  ['Swimming Shirt', 'Socks', 'Sweatshirts'],
#  ['Swimming Shirt', 'Rash Guard', 'Dry Fit V-Neck', 'Hoodies', 'Tech Pants'],
#  ['Swimming Shirt', 'Rash Guard', 'Dry Fit V-Neck'],
#  ['Swimming Shirt', 'Rash Guard', 'Dry Fit V-Neck'],
#  ['Running Shoe',
#   'Swimming Shirt',
#   'Socks',
#   'Sweatshirts',
#   'Modern Pants',
#   'Soccer Shoe',
#   'Rash Guard',
#   'Hoodies',
#   'Tech Pants',
#   'Dry Fit V-Neck'],
#  ['Running Shoe',
#   'Swimming Shirt',
#   'Socks',
#   'Sweatshirts',
#   'Modern Pants',
#   'Soccer Shoe',
#   'Rash Guard',
#   'Tech Pants',
#   'Dry Fit V-Neck',
#   'Hoodies'],
#  ['Running Shoe',
#   'Swimming Shirt',
#   'Rash Guard',
#   'Tech Pants',
#   'Hoodies',
#   'Dry Fit V-Neck'],
#  ['Running Shoe',
#   'Swimming Shirt',
#   'Socks',
#   'Sweatshirts',
#   'Modern Pants',
#   'Dry Fit V-Neck',
#   'Rash Guard',
#   'Tech Pants'],
#  ['Swimming Shirt',
#   'Soccer Shoe',
#   'Hoodies',
#   'Dry Fit V-Neck',
#   'Tech Pants',
#   'Rash Guard'],
#  ['Running Shoe', 'Socks'],
#  ['Socks',
#   'Sweatshirts',
#   'Modern Pants',
#   'Soccer Shoe',
#   'Hoodies',
#   'Rash Guard',
#   'Tech Pants',
#   'Dry Fit V-Neck'],
#  ['Running Shoe', 'Swimming Shirt', 'Rash Guard'],
#  ['Running Shoe',
#   'Swimming Shirt',
#   'Socks',
#   'Sweatshirts',
#   'Modern Pants',
#   'Soccer Shoe',
#   'Hoodies',
#   'Tech Pants',
#   'Rash Guard',
#   'Dry Fit V-Neck']]

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)

# %%
df = pd.DataFrame(te_ary, columns = te.columns_)
pd.set_option('display.max_colwidth', None)
df
# Out:
#     Dry Fit V-Neck  Hoodies  Modern Pants  Rash Guard  Running Shoe  \
# 0            False    False          True       False          True
# 1            False    False         False       False          True
# 2            False    False          True       False          True
# 3            False    False          True       False          True
# 4            False    False          True       False          True
# 5            False    False         False       False          True
# 6            False     True          True        True          True
# 7            False    False         False       False         False
# 8             True     True         False        True         False
# 9             True    False         False        True         False
# 10            True    False         False        True         False
# 11            True     True          True        True          True
# 12            True     True          True        True          True
# 13            True     True         False        True          True
# 14            True    False          True        True          True
# 15            True     True         False        True         False
# 16           False    False         False       False          True
# 17            True     True          True        True         False
# 18           False    False         False        True          True
# 19            True     True          True        True          True
#
#     Soccer Shoe  Socks  Sweatshirts  Swimming Shirt  Tech Pants
# 0         False   True         True           False       False
# 1         False   True         True           False       False
# 2         False   True         True           False       False
# 3         False  False         True           False       False
# 4          True   True         True           False       False
# 5         False   True         True           False       False
# 6         False   True         True           False        True
# 7         False   True         True            True       False
# 8         False  False        False            True        True
# 9         False  False        False            True       False
# 10        False  False        False            True       False
# 11         True   True         True            True        True
# 12         True   True         True            True        True
# 13        False  False        False            True        True
# 14        False   True         True            True        True
# 15         True  False        False            True        True
# 16        False   True        False           False       False
# 17         True   True         True           False        True
# 18        False  False        False            True       False
# 19         True   True         True            True        True

# %%
min_support, min_confidence
# Out:
# (0.5, 0.7)

# %%
freq_itemsets = apriori(df, min_support, use_colnames=True)
freq_itemsets
# Out:
#     support                            itemsets
# 0      0.50                    (Dry Fit V-Neck)
# 1      0.50                      (Modern Pants)
# 2      0.60                        (Rash Guard)
# 3      0.70                      (Running Shoe)
# 4      0.65                             (Socks)
# 5      0.65                       (Sweatshirts)
# 6      0.55                    (Swimming Shirt)
# 7      0.50        (Rash Guard, Dry Fit V-Neck)
# 8      0.50         (Modern Pants, Sweatshirts)
# 9      0.50        (Rash Guard, Swimming Shirt)
# 10     0.55               (Socks, Running Shoe)
# 11     0.55         (Running Shoe, Sweatshirts)
# 12     0.60                (Socks, Sweatshirts)
# 13     0.50  (Socks, Running Shoe, Sweatshirts)

# %%
res = association_rules(freq_itemsets, metric = "confidence", min_threshold = min_confidence)
res
# Out:
#                     antecedents                  consequents  \
# 0                  (Rash Guard)             (Dry Fit V-Neck)
# 1              (Dry Fit V-Neck)                 (Rash Guard)
# 2                (Modern Pants)                (Sweatshirts)
# 3                 (Sweatshirts)               (Modern Pants)
# 4                  (Rash Guard)             (Swimming Shirt)
# 5              (Swimming Shirt)                 (Rash Guard)
# 6                       (Socks)               (Running Shoe)
# 7                (Running Shoe)                      (Socks)
# 8                (Running Shoe)                (Sweatshirts)
# 9                 (Sweatshirts)               (Running Shoe)
# 10                      (Socks)                (Sweatshirts)
# 11                (Sweatshirts)                      (Socks)
# 12        (Socks, Running Shoe)                (Sweatshirts)
# 13         (Socks, Sweatshirts)               (Running Shoe)
# 14  (Running Shoe, Sweatshirts)                      (Socks)
# 15                      (Socks)  (Running Shoe, Sweatshirts)
# 16               (Running Shoe)         (Socks, Sweatshirts)
# 17                (Sweatshirts)        (Socks, Running Shoe)
#
#     antecedent support  consequent support  support  confidence      lift  \
# 0                 0.60                0.50     0.50    0.833333  1.666667
# 1                 0.50                0.60     0.50    1.000000  1.666667
# 2                 0.50                0.65     0.50    1.000000  1.538462
# 3                 0.65                0.50     0.50    0.769231  1.538462
# 4                 0.60                0.55     0.50    0.833333  1.515152
# 5                 0.55                0.60     0.50    0.909091  1.515152
# 6                 0.65                0.70     0.55    0.846154  1.208791
# 7                 0.70                0.65     0.55    0.785714  1.208791
# 8                 0.70                0.65     0.55    0.785714  1.208791
# 9                 0.65                0.70     0.55    0.846154  1.208791
# 10                0.65                0.65     0.60    0.923077  1.420118
# 11                0.65                0.65     0.60    0.923077  1.420118
# 12                0.55                0.65     0.50    0.909091  1.398601
# 13                0.60                0.70     0.50    0.833333  1.190476
# 14                0.55                0.65     0.50    0.909091  1.398601
# 15                0.65                0.55     0.50    0.769231  1.398601
# 16                0.70                0.60     0.50    0.714286  1.190476
# 17                0.65                0.55     0.50    0.769231  1.398601
#
#     leverage  conviction  zhangs_metric
# 0     0.2000    3.000000       1.000000
# 1     0.2000         inf       0.800000
# 2     0.1750         inf       0.700000
# 3     0.1750    2.166667       1.000000
# 4     0.1700    2.700000       0.850000
# 5     0.1700    4.400000       0.755556
# 6     0.0950    1.950000       0.493506
# 7     0.0950    1.633333       0.575758
# 8     0.0950    1.633333       0.575758
# 9     0.0950    1.950000       0.493506
# 10    0.1775    4.550000       0.845238
# 11    0.1775    4.550000       0.845238
# 12    0.1425    3.850000       0.633333
# 13    0.0800    1.800000       0.400000
# 14    0.1425    3.850000       0.633333
# 15    0.1425    1.950000       0.814286
# 16    0.0800    1.400000       0.533333
# 17    0.1425    1.950000       0.814286

# %%
res1 = res[['antecedents', 'consequents', 'support', 'confidence']]
res1
# Out:
#                     antecedents                  consequents  support  \
# 0                  (Rash Guard)             (Dry Fit V-Neck)     0.50
# 1              (Dry Fit V-Neck)                 (Rash Guard)     0.50
# 2                (Modern Pants)                (Sweatshirts)     0.50
# 3                 (Sweatshirts)               (Modern Pants)     0.50
# 4                  (Rash Guard)             (Swimming Shirt)     0.50
# 5              (Swimming Shirt)                 (Rash Guard)     0.50
# 6                       (Socks)               (Running Shoe)     0.55
# 7                (Running Shoe)                      (Socks)     0.55
# 8                (Running Shoe)                (Sweatshirts)     0.55
# 9                 (Sweatshirts)               (Running Shoe)     0.55
# 10                      (Socks)                (Sweatshirts)     0.60
# 11                (Sweatshirts)                      (Socks)     0.60
# 12        (Socks, Running Shoe)                (Sweatshirts)     0.50
# 13         (Socks, Sweatshirts)               (Running Shoe)     0.50
# 14  (Running Shoe, Sweatshirts)                      (Socks)     0.50
# 15                      (Socks)  (Running Shoe, Sweatshirts)     0.50
# 16               (Running Shoe)         (Socks, Sweatshirts)     0.50
# 17                (Sweatshirts)        (Socks, Running Shoe)     0.50
#
#     confidence
# 0     0.833333
# 1     1.000000
# 2     1.000000
# 3     0.769231
# 4     0.833333
# 5     0.909091
# 6     0.846154
# 7     0.785714
# 8     0.785714
# 9     0.846154
# 10    0.923077
# 11    0.923077
# 12    0.909091
# 13    0.833333
# 14    0.909091
# 15    0.769231
# 16    0.714286
# 17    0.769231

# %%
if not res1.empty:
    for index, row in res1.iterrows():
        print(f"Rule: {row['antecedents']} -> {row['consequents']}, \nSupport: {row['support']}, \nConfidence: {row['confidence']}\n")
else:
    print("NO ASSOCIATION RULES FOUND")
# Out:
# Rule: frozenset({'Rash Guard'}) -> frozenset({'Dry Fit V-Neck'}),
# Support: 0.5,
# Confidence: 0.8333333333333334
#
# Rule: frozenset({'Dry Fit V-Neck'}) -> frozenset({'Rash Guard'}),
# Support: 0.5,
# Confidence: 1.0
#
# Rule: frozenset({'Modern Pants'}) -> frozenset({'Sweatshirts'}),
# Support: 0.5,
# Confidence: 1.0
#
# Rule: frozenset({'Sweatshirts'}) -> frozenset({'Modern Pants'}),
# Support: 0.5,
# Confidence: 0.7692307692307692
#
# Rule: frozenset({'Rash Guard'}) -> frozenset({'Swimming Shirt'}),
# Support: 0.5,
# Confidence: 0.8333333333333334
#
# Rule: frozenset({'Swimming Shirt'}) -> frozenset({'Rash Guard'}),
# Support: 0.5,
# Confidence: 0.9090909090909091
#
# Rule: frozenset({'Socks'}) -> frozenset({'Running Shoe'}),
# Support: 0.55,
# Confidence: 0.8461538461538461
#
# Rule: frozenset({'Running Shoe'}) -> frozenset({'Socks'}),
# Support: 0.55,
# Confidence: 0.7857142857142858
#
# Rule: frozenset({'Running Shoe'}) -> frozenset({'Sweatshirts'}),
# Support: 0.55,
# Confidence: 0.7857142857142858
#
# Rule: frozenset({'Sweatshirts'}) -> frozenset({'Running Shoe'}),
# Support: 0.55,
# Confidence: 0.8461538461538461
#
# Rule: frozenset({'Socks'}) -> frozenset({'Sweatshirts'}),
# Support: 0.6,
# Confidence: 0.923076923076923
#
# Rule: frozenset({'Sweatshirts'}) -> frozenset({'Socks'}),
# Support: 0.6,
# Confidence: 0.923076923076923
#
# Rule: frozenset({'Socks', 'Running Shoe'}) -> frozenset({'Sweatshirts'}),
# Support: 0.5,
# Confidence: 0.9090909090909091
#
# Rule: frozenset({'Socks', 'Sweatshirts'}) -> frozenset({'Running Shoe'}),
# Support: 0.5,
# Confidence: 0.8333333333333334
#
# Rule: frozenset({'Running Shoe', 'Sweatshirts'}) -> frozenset({'Socks'}),
# Support: 0.5,
# Confidence: 0.9090909090909091
#
# Rule: frozenset({'Socks'}) -> frozenset({'Running Shoe', 'Sweatshirts'}),
# Support: 0.5,
# Confidence: 0.7692307692307692
#
# Rule: frozenset({'Running Shoe'}) -> frozenset({'Socks', 'Sweatshirts'}),
# Support: 0.5,
# Confidence: 0.7142857142857143
#
# Rule: frozenset({'Sweatshirts'}) -> frozenset({'Socks', 'Running Shoe'}),
# Support: 0.5,
# Confidence: 0.7692307692307692

# %% [markdown]
# # Built-In FP-Growth Algorithm Implementation

# %%
fpgrowth(df, min_support)
# Out:
#     support   itemsets
# 0      0.70        (4)
# 1      0.65        (6)
# 2      0.65        (7)
# 3      0.50        (2)
# 4      0.60        (3)
# 5      0.55        (8)
# 6      0.50        (0)
# 7      0.55     (4, 6)
# 8      0.60     (6, 7)
# 9      0.55     (4, 7)
# 10     0.50  (4, 6, 7)
# 11     0.50     (2, 7)
# 12     0.50     (8, 3)
# 13     0.50     (0, 3)

# %%
frequent_itemsets = fpgrowth(df, min_support, use_colnames=True)
frequent_itemsets
# Out:
#     support                            itemsets
# 0      0.70                      (Running Shoe)
# 1      0.65                             (Socks)
# 2      0.65                       (Sweatshirts)
# 3      0.50                      (Modern Pants)
# 4      0.60                        (Rash Guard)
# 5      0.55                    (Swimming Shirt)
# 6      0.50                    (Dry Fit V-Neck)
# 7      0.55               (Socks, Running Shoe)
# 8      0.60                (Socks, Sweatshirts)
# 9      0.55         (Running Shoe, Sweatshirts)
# 10     0.50  (Socks, Running Shoe, Sweatshirts)
# 11     0.50         (Modern Pants, Sweatshirts)
# 12     0.50        (Rash Guard, Swimming Shirt)
# 13     0.50        (Rash Guard, Dry Fit V-Neck)

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold = min_confidence)
rules
# Out:
#                     antecedents                  consequents  \
# 0                       (Socks)               (Running Shoe)
# 1                (Running Shoe)                      (Socks)
# 2                       (Socks)                (Sweatshirts)
# 3                 (Sweatshirts)                      (Socks)
# 4                (Running Shoe)                (Sweatshirts)
# 5                 (Sweatshirts)               (Running Shoe)
# 6         (Socks, Running Shoe)                (Sweatshirts)
# 7          (Socks, Sweatshirts)               (Running Shoe)
# 8   (Running Shoe, Sweatshirts)                      (Socks)
# 9                       (Socks)  (Running Shoe, Sweatshirts)
# 10               (Running Shoe)         (Socks, Sweatshirts)
# 11                (Sweatshirts)        (Socks, Running Shoe)
# 12               (Modern Pants)                (Sweatshirts)
# 13                (Sweatshirts)               (Modern Pants)
# 14                 (Rash Guard)             (Swimming Shirt)
# 15             (Swimming Shirt)                 (Rash Guard)
# 16                 (Rash Guard)             (Dry Fit V-Neck)
# 17             (Dry Fit V-Neck)                 (Rash Guard)
#
#     antecedent support  consequent support  support  confidence      lift  \
# 0                 0.65                0.70     0.55    0.846154  1.208791
# 1                 0.70                0.65     0.55    0.785714  1.208791
# 2                 0.65                0.65     0.60    0.923077  1.420118
# 3                 0.65                0.65     0.60    0.923077  1.420118
# 4                 0.70                0.65     0.55    0.785714  1.208791
# 5                 0.65                0.70     0.55    0.846154  1.208791
# 6                 0.55                0.65     0.50    0.909091  1.398601
# 7                 0.60                0.70     0.50    0.833333  1.190476
# 8                 0.55                0.65     0.50    0.909091  1.398601
# 9                 0.65                0.55     0.50    0.769231  1.398601
# 10                0.70                0.60     0.50    0.714286  1.190476
# 11                0.65                0.55     0.50    0.769231  1.398601
# 12                0.50                0.65     0.50    1.000000  1.538462
# 13                0.65                0.50     0.50    0.769231  1.538462
# 14                0.60                0.55     0.50    0.833333  1.515152
# 15                0.55                0.60     0.50    0.909091  1.515152
# 16                0.60                0.50     0.50    0.833333  1.666667
# 17                0.50                0.60     0.50    1.000000  1.666667
#
#     leverage  conviction  zhangs_metric
# 0     0.0950    1.950000       0.493506
# 1     0.0950    1.633333       0.575758
# 2     0.1775    4.550000       0.845238
# 3     0.1775    4.550000       0.845238
# 4     0.0950    1.633333       0.575758
# 5     0.0950    1.950000       0.493506
# 6     0.1425    3.850000       0.633333
# 7     0.0800    1.800000       0.400000
# 8     0.1425    3.850000       0.633333
# 9     0.1425    1.950000       0.814286
# 10    0.0800    1.400000       0.533333
# 11    0.1425    1.950000       0.814286
# 12    0.1750         inf       0.700000
# 13    0.1750    2.166667       1.000000
# 14    0.1700    2.700000       0.850000
# 15    0.1700    4.400000       0.755556
# 16    0.2000    3.000000       1.000000
# 17    0.2000         inf       0.800000

# %%
if not rules.empty:
    for index, row in res1.iterrows():
        print(f"Rule: {row['antecedents']} -> {row['consequents']}, \nSupport: {row['support']}, \nConfidence: {row['confidence']}\n")
else:
    print("NO ASSOCIATION RULES FOUND")
# Out:
# Rule: frozenset({'Rash Guard'}) -> frozenset({'Dry Fit V-Neck'}),
# Support: 0.5,
# Confidence: 0.8333333333333334
#
# Rule: frozenset({'Dry Fit V-Neck'}) -> frozenset({'Rash Guard'}),
# Support: 0.5,
# Confidence: 1.0
#
# Rule: frozenset({'Modern Pants'}) -> frozenset({'Sweatshirts'}),
# Support: 0.5,
# Confidence: 1.0
#
# Rule: frozenset({'Sweatshirts'}) -> frozenset({'Modern Pants'}),
# Support: 0.5,
# Confidence: 0.7692307692307692
#
# Rule: frozenset({'Rash Guard'}) -> frozenset({'Swimming Shirt'}),
# Support: 0.5,
# Confidence: 0.8333333333333334
#
# Rule: frozenset({'Swimming Shirt'}) -> frozenset({'Rash Guard'}),
# Support: 0.5,
# Confidence: 0.9090909090909091
#
# Rule: frozenset({'Socks'}) -> frozenset({'Running Shoe'}),
# Support: 0.55,
# Confidence: 0.8461538461538461
#
# Rule: frozenset({'Running Shoe'}) -> frozenset({'Socks'}),
# Support: 0.55,
# Confidence: 0.7857142857142858
#
# Rule: frozenset({'Running Shoe'}) -> frozenset({'Sweatshirts'}),
# Support: 0.55,
# Confidence: 0.7857142857142858
#
# Rule: frozenset({'Sweatshirts'}) -> frozenset({'Running Shoe'}),
# Support: 0.55,
# Confidence: 0.8461538461538461
#
# Rule: frozenset({'Socks'}) -> frozenset({'Sweatshirts'}),
# Support: 0.6,
# Confidence: 0.923076923076923
#
# Rule: frozenset({'Sweatshirts'}) -> frozenset({'Socks'}),
# Support: 0.6,
# Confidence: 0.923076923076923
#
# Rule: frozenset({'Socks', 'Running Shoe'}) -> frozenset({'Sweatshirts'}),
# Support: 0.5,
# Confidence: 0.9090909090909091
#
# Rule: frozenset({'Socks', 'Sweatshirts'}) -> frozenset({'Running Shoe'}),
# Support: 0.5,
# Confidence: 0.8333333333333334
#
# Rule: frozenset({'Running Shoe', 'Sweatshirts'}) -> frozenset({'Socks'}),
# Support: 0.5,
# Confidence: 0.9090909090909091
#
# Rule: frozenset({'Socks'}) -> frozenset({'Running Shoe', 'Sweatshirts'}),
# Support: 0.5,
# Confidence: 0.7692307692307692
#
# Rule: frozenset({'Running Shoe'}) -> frozenset({'Socks', 'Sweatshirts'}),
# Support: 0.5,
# Confidence: 0.7142857142857143
#
# Rule: frozenset({'Sweatshirts'}) -> frozenset({'Socks', 'Running Shoe'}),
# Support: 0.5,
# Confidence: 0.7692307692307692

# %%
# %timeit apriori(df, min_support)
# Out:
# 1.69 ms ± 45.8 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit fpgrowth(df, min_support)
# Out:
# 688 μs ± 29.6 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
